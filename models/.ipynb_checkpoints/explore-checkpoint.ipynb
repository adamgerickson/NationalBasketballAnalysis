# %%
# %pwd
# Out:
# u'C:\\Users\\adamg\\Documents\\AdamCoding\\GitHub\\NationalBasketballAnalysis\\models'

# %%
from data.load import df

# %%
df
# Out:
#        season lg_id    pos           name team_id  fga_per_poss  stl_per_poss  \
# 0     2011-12   NBA     PG   Kyrie Irving     CLE          25.2           1.8
# 1     2012-13   NBA     PG   Kyrie Irving     CLE          27.2           2.3
# 2     2013-14   NBA     PG   Kyrie Irving     CLE          25.6           2.2
# 3     2014-15   NBA     PG   Kyrie Irving     CLE          23.5           2.2
# 4     2015-16   NBA     PG   Kyrie Irving     CLE          27.1           1.7
# 5     2016-17   NBA     PG   Kyrie Irving     CLE          29.3           1.0
# 6      Career   NBA    NaN   Kyrie Irving     NaN          25.7           2.0
# 7     2004-05   NBA     SG     J.R. Smith     NOH          22.1           1.6
# 8     2005-06   NBA     SG     J.R. Smith     NOK          20.0           2.0
# 9     2006-07   NBA     SG     J.R. Smith     DEN          21.6           1.6
# 10    2007-08   NBA     SG     J.R. Smith     DEN          22.8           2.1
# ...

# %%
(df.query('g>100')).query('"pos" != "pos"')
# Out:
# 6       NaN
# 20      NaN
# 35      NaN
# 42      NaN
# 48      NaN
# 61      NaN
# 70      NaN
# 89       SF
# 109     NaN
# 118     NaN
# 127     NaN
# 135     NaN
# 145     NaN
# 149     NaN
# 167     NaN
# 173     NaN
# 185     NaN
# 196     NaN
# 210     NaN
# 230     NaN
# 236     NaN
# 248     NaN
# 253     NaN
# 260     NaN
# 275     NaN
# 287     NaN
# 292     NaN
# 297     NaN
# 302     NaN
# 311     NaN
#        ...
# 2707    NaN
# 2715    NaN
# 2738     PF
# 2748    NaN
# 2761    NaN
# 2767    NaN
# 2782    NaN
# 2791    NaN
# 2807    NaN
# 2820    NaN
# 2825    NaN
# 2833    NaN
# 2843    NaN
# 2850    NaN
# 2859    NaN
# 2867    NaN
# 2875    NaN
# 2883    NaN
# 2891    NaN
# 2897    NaN
# 2903    NaN
# 2918    NaN
# 2940    NaN
# 2956    NaN
# 2966    NaN
# 2980    NaN
# 2987    NaN
# 2997    NaN
# 3013    NaN
# 3025    NaN
# Name: pos, dtype: object
