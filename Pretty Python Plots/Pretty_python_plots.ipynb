# %% [markdown]
# # Dimensionality reduction on NBA player data.

# %%
import altair
import pandas as pd

# %%
data = pd.read_csv('tocsv6581.csv')

# %%
data['3'];

# %%
from altair import datasets, Chart, load_dataset



c = Chart(data).mark_circle().encode(
    x='1',
    y='2',
    color='3',
)

c # save the chart as a variable and display here
# Out:
# <div class="vega-embed" id="d83fd0f2-a408-4fe5-9ce5-4d19ca92841b"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
